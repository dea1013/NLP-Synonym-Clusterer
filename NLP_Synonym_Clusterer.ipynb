# %% [markdown]
# <a href="https://colab.research.google.com/github/dea1013/NLP-Synonym-Clusterer/blob/main/NLP_Synonym_Clusterer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.stem import PorterStemmer
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science Projects/NLP Synonym Clusterer/Vocabulary.csv')
df = df.sort_values(by='Key')
df
# Out:
#        Key  Word                                         Definition
# 0        1     的     indicates possession, like adding 's to a noun
# 1        2     我                                              I; me
# 2        3     你                                     you (singular)
# 3        4     是                                    be; is; are; am
# 4        5     了           indicates a completed or finished action
# ...    ...   ...                                                ...
# 4994  4996  深情厚谊                                profound friendship
# 4995  4997    武侠  knight-errant; a genre of swordplay martial ar...
# 4996  4998    将就           put up with; accept somewhat reluctantly
# 4997  4999    对联  rhyming couplet; vertical written couplet usua...
# 4998  5000    华侨                                   overseas Chinese
#
# [5000 rows x 3 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Cleaning

# %%
# convert to lower case
df['Definition'] = df['Definition'].str.lower()

# remove punctuation
df['Definition'] = df['Definition'].str.replace(r'[^\w\s\d]','',regex=True)

# remove extra white space
df['Definition'] = df['Definition'].str.replace(r' +', ' ',regex=True)

df
# Out:
#        Key  Word                                         Definition  \
# 0        1     的       indicates possession like adding s to a noun
# 1        2     我                                               i me
# 2        3     你                                       you singular
# 3        4     是                                       be is are am
# 4        5     了           indicates a completed or finished action
# ...    ...   ...                                                ...
# 4994  4996  深情厚谊                                profound friendship
# 4995  4997    武侠  knighterrant a genre of swordplay martial arts...
# 4996  4998    将就            put up with accept somewhat reluctantly
# 4997  4999    对联  rhyming couplet vertical written couplet usual...
# 4998  5000    华侨                                   overseas chinese
#
#                                                  Tokens
# 0            [indic, possess, like, ad, s, to, a, noun]
# 1                                               [i, me]
# 2                                       [you, singular]
# 3                                     [be, is, are, am]
# 4               [indic, a, complet, or, finish, action]
# ...                                                 ...
# 4994                             [profound, friendship]
# 4995  [knighterr, a, genr, of, swordplay, martial, a...
# 4996     [put, up, with, accept, somewhat, reluctantli]
# 4997  [rhyme, couplet, vertic, written, couplet, usu...
# 4998                                   [oversea, chine]
#
# [5000 rows x 4 columns]

# %% [markdown]
# ## Tokenization

# %%
# split by whitespace
df['Tokens'] = df['Definition'].apply(lambda x: x.split(' '))

df
# Out:
#        Key  Word                                         Definition  \
# 0        1     的       indicates possession like adding s to a noun
# 1        2     我                                               i me
# 2        3     你                                       you singular
# 3        4     是                                       be is are am
# 4        5     了           indicates a completed or finished action
# ...    ...   ...                                                ...
# 4994  4996  深情厚谊                                profound friendship
# 4995  4997    武侠  knighterrant a genre of swordplay martial arts...
# 4996  4998    将就            put up with accept somewhat reluctantly
# 4997  4999    对联  rhyming couplet vertical written couplet usual...
# 4998  5000    华侨                                   overseas chinese
#
#                                                  Tokens
# 0     [indicates, possession, like, adding, s, to, a...
# 1                                               [i, me]
# 2                                       [you, singular]
# 3                                     [be, is, are, am]
# 4       [indicates, a, completed, or, finished, action]
# ...                                                 ...
# 4994                             [profound, friendship]
# 4995  [knighterrant, a, genre, of, swordplay, martia...
# 4996     [put, up, with, accept, somewhat, reluctantly]
# 4997  [rhyming, couplet, vertical, written, couplet,...
# 4998                                [overseas, chinese]
#
# [5000 rows x 4 columns]

# %% [markdown]
# ## Normalization

# %%
# lemmatization
wordnet = WordNetLemmatizer()
df['Tokens'] = df['Tokens'].apply(lambda x: [wordnet.lemmatize(token,'n' if pos not in ['a', 'r', 'n', 'v'] else pos) for token,pos in pos_tag(x)])

# stemming
# porter = PorterStemmer()
# df['Tokens'] = df['Tokens'].apply(lambda x: [porter.stem(word) for word in x])

df
# Out:
#        Key  Word                                         Definition  \
# 0        1     的       indicates possession like adding s to a noun
# 1        2     我                                               i me
# 2        3     你                                       you singular
# 3        4     是                                       be is are am
# 4        5     了           indicates a completed or finished action
# ...    ...   ...                                                ...
# 4994  4996  深情厚谊                                profound friendship
# 4995  4997    武侠  knighterrant a genre of swordplay martial arts...
# 4996  4998    将就            put up with accept somewhat reluctantly
# 4997  4999    对联  rhyming couplet vertical written couplet usual...
# 4998  5000    华侨                                   overseas chinese
#
#                                                  Tokens
# 0     [indicates, possession, like, adding, s, to, a...
# 1                                               [i, me]
# 2                                       [you, singular]
# 3                                     [be, is, are, am]
# 4       [indicates, a, completed, or, finished, action]
# ...                                                 ...
# 4994                             [profound, friendship]
# 4995  [knighterrant, a, genre, of, swordplay, martia...
# 4996     [put, up, with, accept, somewhat, reluctantly]
# 4997  [rhyming, couplet, vertical, written, couplet,...
# 4998                                [overseas, chinese]
#
# [5000 rows x 4 columns]

# %%
df.sample(10)
# Out:
#        Key Word                                         Definition  \
# 2936  2938   本事  ability skill capability shì this matter liter...
# 1476  1477   基本                                  basic fundamental
# 3853  3855   便条                                      informal note
# 4526  4528   别致                        unique unconventional fancy
# 731    732   随便              as one pleases informal random casual
# 796    797    刀                      knife blade kangxi radical 18
# 4163  4165   可观                            considerable impressive
# 298    299   西瓜                                         watermelon
# 4468  4470  董事长                              chairman of the board
# 3657  3659   徘徊                 pace back and forth hesitate waver
#
#                                                  Tokens
# 2936  [abil, skill, capabl, shì, thi, matter, litera...
# 1476                                 [basic, fundament]
# 3853                                     [inform, note]
# 4526                          [uniqu, unconvent, fanci]
# 731            [as, one, pleas, inform, random, casual]
# 796                   [knife, blade, kangxi, radic, 18]
# 4163                                [consider, impress]
# 298                                        [watermelon]
# 4468                         [chairman, of, the, board]
# 3657             [pace, back, and, forth, hesit, waver]

# %% [markdown]
# # Word Embedding

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# ## BOW

# %% [markdown]
# ## CBOW

# %% [markdown]
# ## Skip-Gram

# %% [markdown]
# ## GloVe

# %% [markdown]
# ## BERT

# %% [markdown]
# # Clustering
